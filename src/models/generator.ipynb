# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model_lib import model_generator

# %%
model_generator("dense", lr=10e-3,relations=[(36, 8), (36, 12), (48, 12), (48, 24)])
# Out:
# Loss
# 	training         	 (min:    0.355, max:    0.436, cur:    0.355)
# 	validation       	 (min:    0.372, max:    0.391, cur:    0.374)
# mean_absolute_error
# 	training         	 (min:    0.551, max:    0.643, cur:    0.551)
# 	validation       	 (min:    0.569, max:    0.589, cur:    0.570)
# mean_squared_error
# 	training         	 (min:    2.688, max:    4.382, cur:    2.688)
# 	validation       	 (min:    3.077, max:    3.602, cur:    3.082)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.137, max:    0.180, cur:    0.137)
# 	validation       	 (min:    0.152, max:    0.161, cur:    0.154)
# rmsle
# 	training         	 (min:    0.370, max:    0.423, cur:    0.370)
# 	validation       	 (min:    0.389, max:    0.401, cur:    0.392)
# root_mean_squared_error
# 	training         	 (min:    1.640, max:    2.093, cur:    1.640)
# 	validation       	 (min:    1.754, max:    1.898, cur:    1.755)
# 272/272 [==============================] - 9s 25ms/step - loss: 0.3337 - mean_squared_logarithmic_error: 0.1256 - mean_squared_error: 2.3928 - mean_absolute_error: 0.5267 - root_mean_squared_error: 1.5475 - rmsle: 0.3543
# 272/272 [==============================] - 9s 25ms/step - loss: 0.3736 - mean_squared_logarithmic_error: 0.1536 - mean_squared_error: 3.0812 - mean_absolute_error: 0.5704 - root_mean_squared_error: 1.7552 - rmsle: 0.3916
# 272/272 [==============================] - 9s 24ms/step - loss: 0.4141 - mean_squared_logarithmic_error: 0.1749 - mean_squared_error: 3.4310 - mean_absolute_error: 0.6179 - root_mean_squared_error: 1.8528 - rmsle: 0.4179

# %%
model_generator("simple_rnn", lr=10e-3,relations=[(36, 8), (36, 12), (48, 12), (48, 24)])
# Out:
# Loss
# 	training         	 (min:    0.389, max:    0.455, cur:    0.389)
# 	validation       	 (min:    0.383, max:    0.401, cur:    0.385)
# mean_absolute_error
# 	training         	 (min:    0.596, max:    0.677, cur:    0.596)
# 	validation       	 (min:    0.581, max:    0.605, cur:    0.582)
# mean_squared_error
# 	training         	 (min:    3.249, max:    4.628, cur:    3.249)
# 	validation       	 (min:    3.318, max:    3.841, cur:    3.375)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.148, max:    0.190, cur:    0.148)
# 	validation       	 (min:    0.155, max:    0.165, cur:    0.155)
# rmsle
# 	training         	 (min:    0.384, max:    0.435, cur:    0.384)
# 	validation       	 (min:    0.393, max:    0.406, cur:    0.394)
# root_mean_squared_error
# 	training         	 (min:    1.803, max:    2.151, cur:    1.803)
# 	validation       	 (min:    1.821, max:    1.960, cur:    1.837)
# 272/272 [==============================] - 8s 22ms/step - loss: 0.3632 - mean_squared_logarithmic_error: 0.1310 - mean_squared_error: 3.1384 - mean_absolute_error: 0.5566 - root_mean_squared_error: 1.7719 - rmsle: 0.3617
# 272/272 [==============================] - 8s 23ms/step - loss: 0.3854 - mean_squared_logarithmic_error: 0.1555 - mean_squared_error: 3.3774 - mean_absolute_error: 0.5815 - root_mean_squared_error: 1.8372 - rmsle: 0.3940
# 272/272 [==============================] - 8s 23ms/step - loss: 0.4231 - mean_squared_logarithmic_error: 0.1751 - mean_squared_error: 3.6532 - mean_absolute_error: 0.6260 - root_mean_squared_error: 1.9113 - rmsle: 0.4182

# %%
model_generator("lstm", lr=10e-3,relations=[(3, 1), (5, 1), (8, 1)])
# Out:
# Loss
# 	training         	 (min:    0.510, max:    0.513, cur:    0.510)
# 	validation       	 (min:    0.475, max:    0.476, cur:    0.476)
# mean_absolute_error
# 	training         	 (min:    0.715, max:    0.718, cur:    0.718)
# 	validation       	 (min:    0.679, max:    0.688, cur:    0.688)
# mean_squared_error
# 	training         	 (min:    5.828, max:    5.861, cur:    5.829)
# 	validation       	 (min:    4.977, max:    5.060, cur:    4.977)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.248, max:    0.254, cur:    0.248)
# 	validation       	 (min:    0.238, max:    0.240, cur:    0.238)
# rmsle
# 	training         	 (min:    0.497, max:    0.502, cur:    0.497)
# 	validation       	 (min:    0.486, max:    0.489, cur:    0.487)
# root_mean_squared_error
# 	training         	 (min:    2.414, max:    2.420, cur:    2.416)
# 	validation       	 (min:    2.230, max:    2.246, cur:    2.230)
# 274/274 [==============================] - 8s 23ms/step - loss: 0.5102 - mean_squared_logarithmic_error: 0.2467 - mean_squared_error: 5.7795 - mean_absolute_error: 0.7212 - root_mean_squared_error: 2.4044 - rmsle: 0.4953
# 274/274 [==============================] - 9s 25ms/step - loss: 0.4762 - mean_squared_logarithmic_error: 0.2381 - mean_squared_error: 4.9780 - mean_absolute_error: 0.6878 - root_mean_squared_error: 2.2301 - rmsle: 0.4866
# 274/274 [==============================] - 9s 27ms/step - loss: 0.5108 - mean_squared_logarithmic_error: 0.2564 - mean_squared_error: 5.3250 - mean_absolute_error: 0.7270 - root_mean_squared_error: 2.3092 - rmsle: 0.5048

# %%
model_generator("autoregressive", lr=10e-3,relations=[(24, 8), (24, 12), (36, 8), (36, 12), (48, 12), (48, 24)])
# Out:
# Loss
# 	training         	 (min:    0.289, max:    0.464, cur:    0.294)
# 	validation       	 (min:    0.336, max:    0.406, cur:    0.337)
# mean_absolute_error
# 	training         	 (min:    0.440, max:    0.653, cur:    0.446)
# 	validation       	 (min:    0.490, max:    0.576, cur:    0.490)
# mean_squared_error
# 	training         	 (min:    1.667, max:    5.075, cur:    1.739)
# 	validation       	 (min:    2.338, max:    4.090, cur:    2.356)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.111, max:    0.201, cur:    0.114)
# 	validation       	 (min:    0.137, max:    0.171, cur:    0.139)
# rmsle
# 	training         	 (min:    0.333, max:    0.447, cur:    0.337)
# 	validation       	 (min:    0.370, max:    0.413, cur:    0.372)
# root_mean_squared_error
# 	training         	 (min:    1.291, max:    2.253, cur:    1.319)
# 	validation       	 (min:    1.529, max:    2.022, cur:    1.535)
# 272/272 [==============================] - 15s 49ms/step - loss: 0.2865 - mean_squared_logarithmic_error: 0.1104 - mean_squared_error: 1.6446 - mean_absolute_error: 0.4362 - root_mean_squared_error: 1.2826 - rmsle: 0.3321
# 272/272 [==============================] - 15s 49ms/step - loss: 0.3374 - mean_squared_logarithmic_error: 0.1385 - mean_squared_error: 2.3566 - mean_absolute_error: 0.4898 - root_mean_squared_error: 1.5348 - rmsle: 0.3720
# 272/272 [==============================] - 15s 50ms/step - loss: 0.3743 - mean_squared_logarithmic_error: 0.1575 - mean_squared_error: 2.6495 - mean_absolute_error: 0.5345 - root_mean_squared_error: 1.6272 - rmsle: 0.3966
