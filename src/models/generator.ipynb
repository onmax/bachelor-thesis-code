# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model_lib import model_generator

# %%
model_generator("dense", lr=10e-3,relations=[(36, 8), (36, 12), (48, 12), (48, 24)])
# Out:
# Loss
# 	training         	 (min:    0.355, max:    0.436, cur:    0.355)
# 	validation       	 (min:    0.372, max:    0.391, cur:    0.374)
# mean_absolute_error
# 	training         	 (min:    0.551, max:    0.643, cur:    0.551)
# 	validation       	 (min:    0.569, max:    0.589, cur:    0.570)
# mean_squared_error
# 	training         	 (min:    2.688, max:    4.382, cur:    2.688)
# 	validation       	 (min:    3.077, max:    3.602, cur:    3.082)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.137, max:    0.180, cur:    0.137)
# 	validation       	 (min:    0.152, max:    0.161, cur:    0.154)
# rmsle
# 	training         	 (min:    0.370, max:    0.423, cur:    0.370)
# 	validation       	 (min:    0.389, max:    0.401, cur:    0.392)
# root_mean_squared_error
# 	training         	 (min:    1.640, max:    2.093, cur:    1.640)
# 	validation       	 (min:    1.754, max:    1.898, cur:    1.755)
# ...

# %%
model_generator("simple_rnn", lr=10e-3,relations=[(36, 8), (36, 12), (48, 12), (48, 24)])
# Out:
# Loss
# 	training         	 (min:    0.389, max:    0.455, cur:    0.389)
# 	validation       	 (min:    0.383, max:    0.401, cur:    0.385)
# mean_absolute_error
# 	training         	 (min:    0.596, max:    0.677, cur:    0.596)
# 	validation       	 (min:    0.581, max:    0.605, cur:    0.582)
# mean_squared_error
# 	training         	 (min:    3.249, max:    4.628, cur:    3.249)
# 	validation       	 (min:    3.318, max:    3.841, cur:    3.375)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.148, max:    0.190, cur:    0.148)
# 	validation       	 (min:    0.155, max:    0.165, cur:    0.155)
# rmsle
# 	training         	 (min:    0.384, max:    0.435, cur:    0.384)
# 	validation       	 (min:    0.393, max:    0.406, cur:    0.394)
# root_mean_squared_error
# 	training         	 (min:    1.803, max:    2.151, cur:    1.803)
# 	validation       	 (min:    1.821, max:    1.960, cur:    1.837)
# ...

# %%
model_generator("lstm", lr=10e-3,relations=[(3, 1), (5, 1), (8, 1)])
# Out:
# Loss
# 	training         	 (min:    0.506, max:    0.509, cur:    0.506)
# 	validation       	 (min:    0.472, max:    0.472, cur:    0.472)
# mean_absolute_error
# 	training         	 (min:    0.735, max:    0.737, cur:    0.737)
# 	validation       	 (min:    0.698, max:    0.702, cur:    0.702)
# mean_squared_error
# 	training         	 (min:    5.861, max:    5.895, cur:    5.862)
# 	validation       	 (min:    5.053, max:    5.072, cur:    5.055)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.244, max:    0.248, cur:    0.244)
# 	validation       	 (min:    0.235, max:    0.235, cur:    0.235)
# rmsle
# 	training         	 (min:    0.492, max:    0.496, cur:    0.492)
# 	validation       	 (min:    0.483, max:    0.483, cur:    0.483)
# root_mean_squared_error
# 	training         	 (min:    2.420, max:    2.425, cur:    2.422)
# 	validation       	 (min:    2.248, max:    2.252, cur:    2.248)
# Epoch 8/150
# ...

# %%
model_generator("autoregressive", max_epochs=20, lr=10e-3, relations=[(8, 3), (8, 5), (12, 1), (12, 3), (12, 5), (24, 1), (24, 3), (24, 5)])
# Out:
# Loss
# 	training         	 (min:    0.253, max:    0.385, cur:    0.253)
# 	validation       	 (min:    0.304, max:    0.333, cur:    0.308)
# mean_absolute_error
# 	training         	 (min:    0.394, max:    0.528, cur:    0.394)
# 	validation       	 (min:    0.451, max:    0.476, cur:    0.455)
# mean_squared_error
# 	training         	 (min:    1.147, max:    3.490, cur:    1.147)
# 	validation       	 (min:    1.731, max:    2.473, cur:    1.769)
# mean_squared_logarithmic_error
# 	training         	 (min:    0.104, max:    0.160, cur:    0.104)
# 	validation       	 (min:    0.128, max:    0.140, cur:    0.130)
# rmsle
# 	training         	 (min:    0.322, max:    0.397, cur:    0.322)
# 	validation       	 (min:    0.357, max:    0.374, cur:    0.360)
# root_mean_squared_error
# 	training         	 (min:    1.071, max:    1.868, cur:    1.071)
# 	validation       	 (min:    1.316, max:    1.572, cur:    1.330)
# ...
